# %% [markdown]
# # This code finds out which departures that are available to the destination that you want, AKA a Path Finder

# %%
import requests
import os
from dotenv import load_dotenv


load_dotenv()
API_KEY = os.getenv("TRAFFICLABS_API_KEY")

# Fetch stops for a given location
def fetch_stops(city_name):
    base_url = "https://api.resrobot.se/v2.1/location.name"
    params = {
        "input": city_name,
        "format": "json",
        "accessId": API_KEY
    }
    response = requests.get(base_url, params=params)
    
    print(f"Fetching stops for {city_name}...")
    print(f"API Response Status Code: {response.status_code}")
    print(f"API Response Content: {response.text}")

    if response.status_code == 200:
        try:
            data = response.json()
        except ValueError as e:
            print(f"Error decoding JSON: {e}")
            return []
        
        stop_data = []
        if "stopLocationOrCoordLocation" in data:
            for item in data["stopLocationOrCoordLocation"]:
                if "StopLocation" in item:
                    stop = item["StopLocation"]
                    stop_data.append({
                        "Name": stop.get("name", "Unknown"),
                        "Latitude": stop.get("lat"),
                        "Longitude": stop.get("lon"),
                        "ID": stop.get("id")
                    })
        print(f"Fetched {len(stop_data)} stops.")
        return stop_data
    else:
        print(f"Failed to fetch stops. Status Code: {response.status_code}")
        return []

# Fetch a journey/route (trip) from start to destination
def fetch_route(from_stop_id, to_stop_id):
    base_url = "https://api.resrobot.se/v2.1/trip"
    params = {
        "originId": from_stop_id,
        "destId": to_stop_id,
        "format": "json",
        "accessId": API_KEY,
        "passlist": True,
        "showPassingPoints": True
    }

    print(f"Fetching route from stop ID {from_stop_id} to {to_stop_id}...")
    response = requests.get(base_url, params=params)

    print(f"API Response Status Code: {response.status_code}")
    print(f"API Response Content: {response.text}")

    if response.status_code == 200:
        try:
            data = response.json()
        except ValueError as e:
            print(f"Error decoding JSON: {e}")
            return []

        print("Route Data:", data)  # Log the entire route data for debugging purposes

        if "Trip" in data:
            print(f"Found {len(data['Trip'])} trips.")
            return data["Trip"]
        else:
            print("No trips found between the stops.")
            return []
    else:
        print(f"Failed to fetch route. Status Code: {response.status_code}")
        return []

# Main function to orchestrate the process
# you can remove the messages if you want. I was just doing a lot of debugging to see where it gives errors
def main():
    origin_city_name = input("Enter the city you are currently in: ").strip()
    if not origin_city_name:
        print("Origin city name cannot be empty.")
        return

    print(f"Fetching stops in {origin_city_name}...")
    origin_stops = fetch_stops(origin_city_name)
    if not origin_stops:
        print(f"No stops found for {origin_city_name}. Exiting...")
        return

    print("\nAvailable stops in your city (Origin):")
    for index, stop in enumerate(origin_stops):
        print(f"{index + 1}. {stop['Name']} (ID: {stop['ID']})")

    try:
        from_stop_choice = int(input("\nSelect the stop you're at by number: ")) - 1
        if from_stop_choice < 0 or from_stop_choice >= len(origin_stops):
            print("Invalid choice. Exiting...")
            return
    except ValueError:
        print("Invalid input. Exiting...")
        return

    from_stop = origin_stops[from_stop_choice]
    from_stop_id = from_stop["ID"]
    print(f"\nYou are at: {from_stop['Name']} (ID: {from_stop_id})")

    destination_city_name = input("\nEnter the destination city: ").strip()
    if not destination_city_name:
        print("Destination city name cannot be empty.")
        return

    print(f"Fetching stops in {destination_city_name}...")
    destination_stops = fetch_stops(destination_city_name)
    if not destination_stops:
        print(f"No stops found for {destination_city_name}. Exiting...")
        return

    print(f"\nAvailable stops in {destination_city_name}:")
    for index, stop in enumerate(destination_stops):
        print(f"{index + 1}. {stop['Name']} (ID: {stop['ID']})")

    try:
        destination_stop_choice = int(input("\nSelect the destination stop by number: ")) - 1
        if destination_stop_choice < 0 or destination_stop_choice >= len(destination_stops):
            print("Invalid choice. Exiting...")
            return
    except ValueError:
        print("Invalid input. Exiting...")
        return

    destination_stop = destination_stops[destination_stop_choice]
    destination_stop_id = destination_stop["ID"]
    print(f"\nYou have selected the destination stop: {destination_stop['Name']} (ID: {destination_stop_id})")

    print(f"\nFetching route from {from_stop['Name']} to {destination_stop['Name']}...")
    route_data = fetch_route(from_stop_id, destination_stop_id)
    # you can remove this but it is there in case something happened you will know why
    if route_data:
        # Debugging route data to inspect the structure 
        print("\nRoute details:")  # Start printing the route details
        for connection in route_data:
            print(f"Connection Data: {connection}")  # Print the entire connection to inspect its structure
            
            # Now check if the keys 'from' and 'to' exist in the connection, and print based on that
            if 'from' in connection and 'to' in connection:
                print(f"Connection from {connection['from']['name']} to {connection['to']['name']}")
                for leg in connection.get("LegList", {}).get("Leg", []):
                    transport = leg.get("Product", {}).get("name", "Unknown")
                    departure_time = leg.get("Origin", {}).get("dateTime", "Unknown")
                    arrival_time = leg.get("Destination", {}).get("dateTime", "Unknown")
                    origin = leg.get("Origin", {}).get("name", "Unknown")
                    destination = leg.get("Destination", {}).get("name", "Unknown")
                    line = leg.get("Product", {}).get("line", "Unknown")

                    print(f"Take {transport} {line} from {origin} to {destination}.")
                    print(f"Departure: {departure_time}, Arrival: {arrival_time}")
                    print("-" * 40)
            else:
                print("No valid connection found in this route.")
    else:
        print("No route data available.")


if __name__ == "__main__":
    main()
# Out:
# Fetching stops in Partille...
# Fetching stops for Partille...
# API Response Status Code: 200
# API Response Content: {"stopLocationOrCoordLocation":[{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"16"},{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=PARTILLE@X=12102861@Y=57740870@U=1@L=740098044@B=1@p=1738039011@","extId":"740098044","name":"PARTILLE","lon":12.102861,"lat":57.74087,"weight":1711,"products":144,"meta":true,"minimumChangeDuration":"PT26M"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"16"},{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Partille station@X=12102861@Y=57740870@U=1@L=740000132@B=1@p=1738039011@","extId":"740000132","name":"Partille station","lon":12.102861,"lat":57.74087,"weight":1711,"products":144,"minimumChangeDuration":"PT5M"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Partille arena@X=12118016@Y=57741050@U=1@L=740072673@B=1@p=1738039011@","extId":"740072673","name":"Partille arena","lon":12.118016,"lat":57.74105,"weight":518,"products":128,"minimumChangeDuration":"PT26M"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"16"},{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@B=1@p=1738039011@","extId":"740015667","name":"Partille centrum","lon":12.105252,"lat":57.738623,"weight":518,"products":144,"minimumChangeDuration":"PT3M"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Partille Hålldammen@X=12106429@Y=57733562@U=1@L=740015671@B=1@p=1738039011@","extId":"740015671","name":"Partille Hålldammen","lon":12.106429,"lat":57.733562,"weight":518,"products":128,"minimumChangeDuration":"PT0S"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Partille port@X=12122808@Y=57740978@U=1@L=740059976@B=1@p=1738039011@","extId":"740059976","name":"Partille port","lon":12.122808,"lat":57.740978,"weight":518,"products":128,"minimumChangeDuration":"PT0S"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Persplatsen (Partille kn)@X=12065492@Y=57720950@U=1@L=740060009@B=1@p=1738039011@","extId":"740060009","name":"Persplatsen (Partille kn)","lon":12.065492,"lat":57.72095,"weight":518,"products":128,"minimumChangeDuration":"PT0S"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"16"},{"icon":{"res":"prod_gen"},"cls":"128"},{"icon":{"res":"prod_gen"},"cls":"512"}],"timezoneOffset":60,"id":"A=1@O=Jonsered station (Partille kn)@X=12173803@Y=57749958@U=1@L=740015675@B=1@p=1738039011@","extId":"740015675","name":"Jonsered station (Partille kn)","lon":12.173803,"lat":57.749958,"weight":1192,"products":656,"minimumChangeDuration":"PT5M"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"16"},{"icon":{"res":"prod_gen"},"cls":"128"},{"icon":{"res":"prod_gen"},"cls":"512"}],"timezoneOffset":60,"id":"A=1@O=Jonsered Jons väg (Partille kn)@X=12174136@Y=57745616@U=1@L=740025032@B=1@p=1738039011@","extId":"740025032","name":"Jonsered Jons väg (Partille kn)","lon":12.174136,"lat":57.745616,"weight":526,"products":656,"minimumChangeDuration":"PT5M"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Allévägen (Partille kn)@X=12074922@Y=57732771@U=1@L=740059960@B=1@p=1738039011@","extId":"740059960","name":"Allévägen (Partille kn)","lon":12.074922,"lat":57.732771,"weight":518,"products":128,"minimumChangeDuration":"PT0S"}}],"TechnicalMessages":{"TechnicalMessage":[{"value":"2025-01-28 17:17:50","key":"requestTime"},{"value":"ttp=16439#16603 plancode0=02hrp planid=1738039011 planid0=1738039011 planid_adr=1479298166 plancode_adr=q0r10 srvv=5.45.SAMTRAFIKEN.15.0.1 (customer/hcusamtrafiken/release/2023.10.0) [2023-10-19] tlibv=TRFVER: rel/pproxy/4.00.0 2022-10-24 18:24:51 +0200 Relay_EnrichmentProxy v1 jno=1 ...
# Fetched 10 stops.
#
# Available stops in your city (Origin):
# 1. PARTILLE (ID: A=1@O=PARTILLE@X=12102861@Y=57740870@U=1@L=740098044@B=1@p=1738039011@)
# 2. Partille station (ID: A=1@O=Partille station@X=12102861@Y=57740870@U=1@L=740000132@B=1@p=1738039011@)
# 3. Partille arena (ID: A=1@O=Partille arena@X=12118016@Y=57741050@U=1@L=740072673@B=1@p=1738039011@)
# 4. Partille centrum (ID: A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@B=1@p=1738039011@)
# 5. Partille Hålldammen (ID: A=1@O=Partille Hålldammen@X=12106429@Y=57733562@U=1@L=740015671@B=1@p=1738039011@)
# 6. Partille port (ID: A=1@O=Partille port@X=12122808@Y=57740978@U=1@L=740059976@B=1@p=1738039011@)
# 7. Persplatsen (Partille kn) (ID: A=1@O=Persplatsen (Partille kn)@X=12065492@Y=57720950@U=1@L=740060009@B=1@p=1738039011@)
# 8. Jonsered station (Partille kn) (ID: A=1@O=Jonsered station (Partille kn)@X=12173803@Y=57749958@U=1@L=740015675@B=1@p=1738039011@)
# 9. Jonsered Jons väg (Partille kn) (ID: A=1@O=Jonsered Jons väg (Partille kn)@X=12174136@Y=57745616@U=1@L=740025032@B=1@p=1738039011@)
# 10. Allévägen (Partille kn) (ID: A=1@O=Allévägen (Partille kn)@X=12074922@Y=57732771@U=1@L=740059960@B=1@p=1738039011@)
#
# You are at: Partille centrum (ID: A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@B=1@p=1738039011@)
# Fetching stops in Angered...
# Fetching stops for Angered...
# API Response Status Code: 200
# API Response Content: {"stopLocationOrCoordLocation":[{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"64"},{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Angered centrum (Göteborg kn)@X=12049213@Y=57796073@U=1@L=740025606@B=1@p=1738039011@","extId":"740025606","name":"Angered centrum (Göteborg kn)","lon":12.049213,"lat":57.796073,"weight":4251,"products":192,"minimumChangeDuration":"PT5M"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@B=1@p=1738039011@","extId":"740015553","name":"Angered Kyrka (Göteborg kn)","lon":12.095975,"lat":57.788297,"weight":518,"products":128,"minimumChangeDuration":"PT5M"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Angereds Storåsväg (Göteborg kn)@X=12050561@Y=57772863@U=1@L=740059074@B=1@p=1738039011@","extId":"740059074","name":"Angereds Storåsväg (Göteborg kn)","lon":12.050561,"lat":57.772863,"weight":518,"products":128,"minimumChangeDuration":"PT5M"}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Angeredsvinkeln (Göteborg kn)@X=12043694@Y=57800432@U=1@L=740059073@B=1@p=1738039011@","extId":"740059073","name":"Angeredsvinkeln (Göteborg kn)","lon":12.043694,"lat":57.800432,"weight":518,"products":128,"minimumChangeDuration":"PT0S"}},{"CoordLocation":{"links":[{"link":[{"rel":"refine","href":"https://api.resrobot.se/v2.1/location.name?input=Angereds+kyrkv%C3%A4g%2C+G%C3%B6teborg&refineId=A%3D2%40O%3DAngereds+kyrkv%C3%A4g%2C+G%C3%B6teborg%40X%3D12100029%40Y%3D57787794%40U%3D174%40b%3D980002513%40B%3D1%40p%3D1479298166%40&type=A"}]}],"icon":{"res":"loc_addr"},"id":"A=2@O=Angereds kyrkväg, Göteborg@X=12100029@Y=57787794@U=174@b=980002513@B=1@p=1479298166@","name":"Angereds kyrkväg, Göteborg","type":"ADR","lon":12.100029,"lat":57.787794,"refinable":true}},{"CoordLocation":{"links":[{"link":[{"rel":"refine","href":"https://api.resrobot.se/v2.1/location.name?input=Angereds+lastgata%2C+G%C3%B6teborg&refineId=A%3D2%40O%3DAngereds+lastgata%2C+G%C3%B6teborg%40X%3D12050193%40Y%3D57796369%40U%3D174%40b%3D980002514%40B%3D1%40p%3D1479298166%40&type=A"}]}],"icon":{"res":"loc_addr"},"id":"A=2@O=Angereds lastgata, Göteborg@X=12050193@Y=57796369@U=174@b=980002514@B=1@p=1479298166@","name":"Angereds lastgata, Göteborg","type":"ADR","lon":12.050193,"lat":57.796369,"refinable":true}},{"CoordLocation":{"links":[{"link":[{"rel":"refine","href":"https://api.resrobot.se/v2.1/location.name?input=Angereds+stor%C3%A5sv%C3%A4g%2C+G%C3%B6teborg&refineId=A%3D2%40O%3DAngereds+stor%C3%A5sv%C3%A4g%2C+G%C3%B6teborg%40X%3D12048170%40Y%3D57783695%40U%3D174%40b%3D980002515%40B%3D1%40p%3D1479298166%40&type=A"}]}],"icon":{"res":"loc_addr"},"id":"A=2@O=Angereds storåsväg, Göteborg@X=12048170@Y=57783695@U=174@b=980002515@B=1@p=1479298166@","name":"Angereds storåsväg, Göteborg","type":"ADR","lon":12.04817,"lat":57.783695,"refinable":true}},{"CoordLocation":{"links":[{"link":[{"rel":"refine","href":"https://api.resrobot.se/v2.1/location.name?input=Angereds+torg%2C+G%C3%B6teborg&refineId=A%3D2%40O%3DAngereds+torg%2C+G%C3%B6teborg%40X%3D12050957%40Y%3D57796666%40U%3D174%40b%3D980002516%40B%3D1%40p%3D1479298166%40&type=A"}]}],"icon":{"res":"loc_addr"},"id":"A=2@O=Angereds torg, Göteborg@X=12050957@Y=57796666@U=174@b=980002516@B=1@p=1479298166@","name":"Angereds torg, Göteborg","type":"ADR","lon":12.050957,"lat":57.796666,"refinable":true}},{"StopLocation":{"productAtStop":[{"icon":{"res":"prod_gen"},"cls":"128"}],"timezoneOffset":60,"id":"A=1@O=Angerdshestravägen (Jönköping kn)@X=13987377@Y=57753473@U=1@L=740039567@B=1@p=1738039011@","extId":"740039567","name":"Angerdshestravägen (Jönköping kn)","lon":13.987377,"lat":57.753473,"weight":518,"products":128,"minimumChangeDuration":"PT0S"}},{"CoordLocation":{"links":[{"link":[{"rel":"refine","href":"https ...
# Fetched 5 stops.
#
# Available stops in Angered:
# 1. Angered centrum (Göteborg kn) (ID: A=1@O=Angered centrum (Göteborg kn)@X=12049213@Y=57796073@U=1@L=740025606@B=1@p=1738039011@)
# 2. Angered Kyrka (Göteborg kn) (ID: A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@B=1@p=1738039011@)
# 3. Angereds Storåsväg (Göteborg kn) (ID: A=1@O=Angereds Storåsväg (Göteborg kn)@X=12050561@Y=57772863@U=1@L=740059074@B=1@p=1738039011@)
# 4. Angeredsvinkeln (Göteborg kn) (ID: A=1@O=Angeredsvinkeln (Göteborg kn)@X=12043694@Y=57800432@U=1@L=740059073@B=1@p=1738039011@)
# 5. Angerdshestravägen (Jönköping kn) (ID: A=1@O=Angerdshestravägen (Jönköping kn)@X=13987377@Y=57753473@U=1@L=740039567@B=1@p=1738039011@)
#
# You have selected the destination stop: Angered Kyrka (Göteborg kn) (ID: A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@B=1@p=1738039011@)
#
# Fetching route from Partille centrum to Angered Kyrka (Göteborg kn)...
# Fetching route from stop ID A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@B=1@p=1738039011@ to A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@B=1@p=1738039011@...
# API Response Status Code: 200
# API Response Content: {"Trip":[{"Origin":{"name":"Partille centrum","type":"ST","id":"A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@","extId":"740015667","lon":12.105252,"lat":57.738623,"routeIdx":0,"prognosisType":"PROGNOSED","time":"17:22:00","date":"2025-01-28","minimumChangeDuration":"PT3M"},"Destination":{"name":"Angered Kyrka (Göteborg kn)","type":"ST","id":"A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@","extId":"740015553","lon":12.095975,"lat":57.788297,"routeIdx":22,"prognosisType":"PROGNOSED","time":"17:58:00","date":"2025-01-28","minimumChangeDuration":"PT5M"},"ServiceDays":[{"planningPeriodBegin":"2025-01-02","planningPeriodEnd":"2025-06-15","sDaysR":"mån - fre","sDaysI":"utom 18., 21. apr, 1., 29. maj, 6. jun","sDaysB":"0000027CF9F3E7CF9F3E7CF9F3C3CE9F3E7CE9E3E0"}],"LegList":{"Leg":[{"Origin":{"name":"Partille centrum","type":"ST","id":"A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@","extId":"740015667","lon":12.105252,"lat":57.738623,"routeIdx":0,"prognosisType":"PROGNOSED","time":"17:22:00","date":"2025-01-28","minimumChangeDuration":"PT3M"},"Destination":{"name":"Linnarhultsvägen (Göteborg kn)","type":"ST","id":"A=1@O=Linnarhultsvägen (Göteborg kn)@X=12064593@Y=57776611@U=1@L=740059414@","extId":"740059414","lon":12.064593,"lat":57.776611,"routeIdx":6,"prognosisType":"PROGNOSED","time":"17:40:00","date":"2025-01-28","minimumChangeDuration":"PT5M"},"Notes":{"Note":[{"value":"Lag 2015:953 tillämpas","key":"EG","type":"A","routeIdxFrom":0,"routeIdxTo":6,"txtN":"Lag 2015:953 tillämpas"}]},"JourneyDetailRef":{"ref":"1|28001|1|1|28012025"},"JourneyStatus":"P","Product":[{"icon":{"res":"prod_gen"},"operatorInfo":{"name":"Västtrafik","nameS":"279","nameN":"279","nameL":"Västtrafik","id":"279"},"name":"Länstrafik - Buss 74","internalName":"Länstrafik - Buss 74","displayNumber":"74","num":"74","line":"74","lineId":"1279507400001","catOut":"BLT","catIn":"BLT","catCode":"7","cls":"128","catOutS":"BLT","catOutL":"Länstrafik - Buss","operatorCode":"279","operator":"Västtrafik","admin":"279___","routeIdxFrom":0,"routeIdxTo":6,"matchId":"74;5074;74"}],"Stops":{"Stop":[{"name":"Partille centrum","id":"A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@","extId":"740015667","routeIdx":0,"lon":12.105252,"lat":57.738623,"depPrognosisType":"PROGNOSED","depTime":"17:22:00","depDate":"2025-01-28","depDir":"Angered centrum (Göteborg kn)","minimumChangeDuration":"PT3M"},{"name":"Artles torg (Partille kn)","id":"A=1@O=Artles torg (Partille kn)@X=12093719@Y=57739971@U=1@L=740060017@","extId":"740060017","routeIdx":1,"lon":12.093719,"lat":57.739971,"depTime":"17:23:00","depDate":"2025-01-28","arrTime":"17:23:00","arrDate":"2025-01-28","minimumChangeDuration":"PT5M"},{"name":"Jennyhill (Partille kn)","id":"A=1@O=Jennyhill (Partille kn)@X=12085062@Y=57741301@U=1@L=740060018@","extId":"740060018","routeIdx":2,"lon":12.085062,"lat":57.741301,"depTime":"17:24:00","depDate":"2025-01-28","arrTime":"17:24:00","arrDate":"2025-01-28","minimumChangeDuration":"PT0S"},{"name":"Bergsjön Komettorget (Göteborg kn)","id":"A=1@O=Bergsjön Komettorget (Göteborg kn)@X=12071398@Y=57751091@U=1@L=740025646@","extId":"740025646","routeIdx":3,"lon":12.071398,"lat":57.751091,"depTime":"17:31:00","depDate":"2025-01-28","arrTime":"17:31:00","arrDate":"2025-01-28","minimumChangeDuration":"PT3M"},{"name":"Rymdtorget Buss (Göteborg kn)","id":"A=1@O=Rymdtorget Buss (Göteborg kn)@X=12072783@Y=57756934@U=1@L=740059521@","extId":"740059521","routeIdx":4,"lon":12.072783,"lat":57.756934,"depTime":"17:35:00","depDate":"2025-01-28","arrTime":"17:35:00","arrDate":"2025-01-28","minimumChangeDuration":"PT3M"},{"name":"Bergsjödalen (Göteborg kn)","id":"A=1@O=Bergsjödalen (Göteborg kn)@X=12074940@Y=57759334@U=1@L=740059117@","extId":"740059117","routeIdx":5,"lon":12.07494,"lat":57.759334,"depTime":"17:35:00","depDate":"2025-01-28","arrTime":"17:35:00","arrDate":"2025-01-28","minimumChangeDuration":"PT0S"},{"name":"Li ...
# Route Data: {'Trip': [{'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '17:22:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Angered Kyrka (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@', 'extId': '740015553', 'lon': 12.095975, 'lat': 57.788297, 'routeIdx': 22, 'prognosisType': 'PROGNOSED', 'time': '17:58:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'ServiceDays': [{'planningPeriodBegin': '2025-01-02', 'planningPeriodEnd': '2025-06-15', 'sDaysR': 'mån - fre', 'sDaysI': 'utom 18., 21. apr, 1., 29. maj, 6. jun', 'sDaysB': '0000027CF9F3E7CF9F3E7CF9F3C3CE9F3E7CE9E3E0'}], 'LegList': {'Leg': [{'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '17:22:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Linnarhultsvägen (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Linnarhultsvägen (Göteborg kn)@X=12064593@Y=57776611@U=1@L=740059414@', 'extId': '740059414', 'lon': 12.064593, 'lat': 57.776611, 'routeIdx': 6, 'prognosisType': 'PROGNOSED', 'time': '17:40:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas', 'key': 'EG', 'type': 'A', 'routeIdxFrom': 0, 'routeIdxTo': 6, 'txtN': 'Lag 2015:953 tillämpas'}]}, 'JourneyDetailRef': {'ref': '1|28001|1|1|28012025'}, 'JourneyStatus': 'P', 'Product': [{'icon': {'res': 'prod_gen'}, 'operatorInfo': {'name': 'Västtrafik', 'nameS': '279', 'nameN': '279', 'nameL': 'Västtrafik', 'id': '279'}, 'name': 'Länstrafik - Buss 74', 'internalName': 'Länstrafik - Buss 74', 'displayNumber': '74', 'num': '74', 'line': '74', 'lineId': '1279507400001', 'catOut': 'BLT', 'catIn': 'BLT', 'catCode': '7', 'cls': '128', 'catOutS': 'BLT', 'catOutL': 'Länstrafik - Buss', 'operatorCode': '279', 'operator': 'Västtrafik', 'admin': '279___', 'routeIdxFrom': 0, 'routeIdxTo': 6, 'matchId': '74;5074;74'}], 'Stops': {'Stop': [{'name': 'Partille centrum', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'routeIdx': 0, 'lon': 12.105252, 'lat': 57.738623, 'depPrognosisType': 'PROGNOSED', 'depTime': '17:22:00', 'depDate': '2025-01-28', 'depDir': 'Angered centrum (Göteborg kn)', 'minimumChangeDuration': 'PT3M'}, {'name': 'Artles torg (Partille kn)', 'id': 'A=1@O=Artles torg (Partille kn)@X=12093719@Y=57739971@U=1@L=740060017@', 'extId': '740060017', 'routeIdx': 1, 'lon': 12.093719, 'lat': 57.739971, 'depTime': '17:23:00', 'depDate': '2025-01-28', 'arrTime': '17:23:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, {'name': 'Jennyhill (Partille kn)', 'id': 'A=1@O=Jennyhill (Partille kn)@X=12085062@Y=57741301@U=1@L=740060018@', 'extId': '740060018', 'routeIdx': 2, 'lon': 12.085062, 'lat': 57.741301, 'depTime': '17:24:00', 'depDate': '2025-01-28', 'arrTime': '17:24:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT0S'}, {'name': 'Bergsjön Komettorget (Göteborg kn)', 'id': 'A=1@O=Bergsjön Komettorget (Göteborg kn)@X=12071398@Y=57751091@U=1@L=740025646@', 'extId': '740025646', 'routeIdx': 3, 'lon': 12.071398, 'lat': 57.751091, 'depTime': '17:31:00', 'depDate': '2025-01-28', 'arrTime': '17:31:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, {'name': 'Rymdtorget Buss (Göteborg kn)', 'id': 'A=1@O=Rymdtorget Buss (Göteborg kn)@X=12072783@Y=57756934@U=1@L=740059521@', 'extId': '740059521', 'routeIdx': 4, 'lon': 12.072783, 'lat': 57.756934, 'depTime': '17:35:00', 'depDate': '2025-01-28', 'arrTime': '17:35:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, {'name': 'Bergsjödalen (Göteborg  ...
# Found 5 trips.
#
# Route details:
# Connection Data: {'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '17:22:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Angered Kyrka (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@', 'extId': '740015553', 'lon': 12.095975, 'lat': 57.788297, 'routeIdx': 22, 'prognosisType': 'PROGNOSED', 'time': '17:58:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'ServiceDays': [{'planningPeriodBegin': '2025-01-02', 'planningPeriodEnd': '2025-06-15', 'sDaysR': 'mån - fre', 'sDaysI': 'utom 18., 21. apr, 1., 29. maj, 6. jun', 'sDaysB': '0000027CF9F3E7CF9F3E7CF9F3C3CE9F3E7CE9E3E0'}], 'LegList': {'Leg': [{'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '17:22:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Linnarhultsvägen (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Linnarhultsvägen (Göteborg kn)@X=12064593@Y=57776611@U=1@L=740059414@', 'extId': '740059414', 'lon': 12.064593, 'lat': 57.776611, 'routeIdx': 6, 'prognosisType': 'PROGNOSED', 'time': '17:40:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas', 'key': 'EG', 'type': 'A', 'routeIdxFrom': 0, 'routeIdxTo': 6, 'txtN': 'Lag 2015:953 tillämpas'}]}, 'JourneyDetailRef': {'ref': '1|28001|1|1|28012025'}, 'JourneyStatus': 'P', 'Product': [{'icon': {'res': 'prod_gen'}, 'operatorInfo': {'name': 'Västtrafik', 'nameS': '279', 'nameN': '279', 'nameL': 'Västtrafik', 'id': '279'}, 'name': 'Länstrafik - Buss 74', 'internalName': 'Länstrafik - Buss 74', 'displayNumber': '74', 'num': '74', 'line': '74', 'lineId': '1279507400001', 'catOut': 'BLT', 'catIn': 'BLT', 'catCode': '7', 'cls': '128', 'catOutS': 'BLT', 'catOutL': 'Länstrafik - Buss', 'operatorCode': '279', 'operator': 'Västtrafik', 'admin': '279___', 'routeIdxFrom': 0, 'routeIdxTo': 6, 'matchId': '74;5074;74'}], 'Stops': {'Stop': [{'name': 'Partille centrum', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'routeIdx': 0, 'lon': 12.105252, 'lat': 57.738623, 'depPrognosisType': 'PROGNOSED', 'depTime': '17:22:00', 'depDate': '2025-01-28', 'depDir': 'Angered centrum (Göteborg kn)', 'minimumChangeDuration': 'PT3M'}, {'name': 'Artles torg (Partille kn)', 'id': 'A=1@O=Artles torg (Partille kn)@X=12093719@Y=57739971@U=1@L=740060017@', 'extId': '740060017', 'routeIdx': 1, 'lon': 12.093719, 'lat': 57.739971, 'depTime': '17:23:00', 'depDate': '2025-01-28', 'arrTime': '17:23:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, {'name': 'Jennyhill (Partille kn)', 'id': 'A=1@O=Jennyhill (Partille kn)@X=12085062@Y=57741301@U=1@L=740060018@', 'extId': '740060018', 'routeIdx': 2, 'lon': 12.085062, 'lat': 57.741301, 'depTime': '17:24:00', 'depDate': '2025-01-28', 'arrTime': '17:24:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT0S'}, {'name': 'Bergsjön Komettorget (Göteborg kn)', 'id': 'A=1@O=Bergsjön Komettorget (Göteborg kn)@X=12071398@Y=57751091@U=1@L=740025646@', 'extId': '740025646', 'routeIdx': 3, 'lon': 12.071398, 'lat': 57.751091, 'depTime': '17:31:00', 'depDate': '2025-01-28', 'arrTime': '17:31:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, {'name': 'Rymdtorget Buss (Göteborg kn)', 'id': 'A=1@O=Rymdtorget Buss (Göteborg kn)@X=12072783@Y=57756934@U=1@L=740059521@', 'extId': '740059521', 'routeIdx': 4, 'lon': 12.072783, 'lat': 57.756934, 'depTime': '17:35:00', 'depDate': '2025-01-28', 'arrTime': '17:35:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, {'name': 'Bergsjödalen (Göteborg kn)', ...
# No valid connection found in this route.
# Connection Data: {'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '17:31:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Angered Kyrka (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@', 'extId': '740015553', 'lon': 12.095975, 'lat': 57.788297, 'routeIdx': 21, 'prognosisType': 'PROGNOSED', 'time': '18:06:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'ServiceDays': [{'planningPeriodBegin': '2025-01-02', 'planningPeriodEnd': '2025-06-15', 'sDaysR': 'mån - fre', 'sDaysI': 'utom 18., 21. apr, 1., 29. maj, 6. jun', 'sDaysB': '0000027CF9F3E7CF9F3E7CF9F3C3CE9F3E7CE9E3E0'}], 'LegList': {'Leg': [{'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '17:31:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Göteborg Svingeln', 'type': 'ST', 'id': 'A=1@O=Göteborg Svingeln@X=11991080@Y=57713147@U=1@L=740015597@', 'extId': '740015597', 'lon': 11.99108, 'lat': 57.713147, 'routeIdx': 1, 'prognosisType': 'PROGNOSED', 'time': '17:40:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas', 'key': 'EG', 'type': 'A', 'routeIdxFrom': 0, 'routeIdxTo': 1, 'txtN': 'Lag 2015:953 tillämpas'}]}, 'JourneyDetailRef': {'ref': '1|101992|4|1|28012025'}, 'JourneyStatus': 'P', 'Product': [{'icon': {'res': 'prod_gen'}, 'operatorInfo': {'name': 'Västtrafik', 'nameS': '279', 'nameN': '279', 'nameL': 'Västtrafik', 'id': '279'}, 'name': 'Länstrafik - Buss X1', 'internalName': 'Länstrafik - Buss X1', 'displayNumber': 'X1', 'num': 'X1', 'line': 'X1', 'lineId': '1279521200001', 'catOut': 'BLT', 'catIn': 'BLT', 'catCode': '7', 'cls': '128', 'catOutS': 'BLT', 'catOutL': 'Länstrafik - Buss', 'operatorCode': '279', 'operator': 'Västtrafik', 'admin': '279___', 'routeIdxFrom': 0, 'routeIdxTo': 1, 'matchId': 'X1;5212;155'}], 'Stops': {'Stop': [{'name': 'Partille centrum', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'routeIdx': 0, 'lon': 12.105252, 'lat': 57.738623, 'depPrognosisType': 'PROGNOSED', 'depTime': '17:31:00', 'depDate': '2025-01-28', 'depDir': 'Hornkamsgatan (Göteborg kn)', 'minimumChangeDuration': 'PT3M'}, {'name': 'Göteborg Svingeln', 'id': 'A=1@O=Göteborg Svingeln@X=11991080@Y=57713147@U=1@L=740015597@', 'extId': '740015597', 'routeIdx': 1, 'lon': 11.99108, 'lat': 57.713147, 'arrTime': '17:40:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT5M'}]}, 'JourneyDetail': {'ref': '1|101992|4|1|28012025', 'dayOfOperation': '2025-01-28'}, 'id': '0', 'idx': 0, 'name': 'Länstrafik - Buss X1', 'number': 'X1', 'category': 'BLT', 'type': 'JNY', 'reachable': True, 'waitingState': 'UNDEF', 'direction': 'Hornkamsgatan (Göteborg kn)', 'directionFlag': '1', 'duration': 'PT9M', 'minimumChangeDuration': 'PT5M'}, {'Origin': {'name': 'Göteborg Svingeln', 'type': 'ST', 'id': 'A=1@O=Göteborg Svingeln@X=11991080@Y=57713147@U=1@L=740015597@', 'extId': '740015597', 'lon': 11.99108, 'lat': 57.713147, 'routeIdx': 15, 'prognosisType': 'PROGNOSED', 'time': '17:46:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'Destination': {'name': 'Angered Kyrka (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@', 'extId': '740015553', 'lon': 12.095975, 'lat': 57.788297, 'routeIdx': 21, 'prognosisType': 'PROGNOSED', 'time': '18:06:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas', 'key': 'EG', 'type': 'A', 'routeIdxFrom': 15, 'routeIdxTo': 21, 'txtN': ...
# No valid connection found in this route.
# Connection Data: {'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '17:42:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Angered Kyrka (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@', 'extId': '740015553', 'lon': 12.095975, 'lat': 57.788297, 'routeIdx': 21, 'prognosisType': 'PROGNOSED', 'time': '18:16:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'ServiceDays': [{'planningPeriodBegin': '2025-01-02', 'planningPeriodEnd': '2025-06-15', 'sDaysR': 'mån - fre', 'sDaysI': 'utom 18., 21. apr, 1., 29. maj, 6. jun', 'sDaysB': '0000027CF9F3E7CF9F3E7CF9F3C3CE9F3E7CE9E3E0'}], 'LegList': {'Leg': [{'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '17:42:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Linnarhultsvägen (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Linnarhultsvägen (Göteborg kn)@X=12064593@Y=57776611@U=1@L=740059414@', 'extId': '740059414', 'lon': 12.064593, 'lat': 57.776611, 'routeIdx': 6, 'prognosisType': 'PROGNOSED', 'time': '18:00:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas', 'key': 'EG', 'type': 'A', 'routeIdxFrom': 0, 'routeIdxTo': 6, 'txtN': 'Lag 2015:953 tillämpas'}]}, 'JourneyDetailRef': {'ref': '1|28001|2|1|28012025'}, 'JourneyStatus': 'P', 'Product': [{'icon': {'res': 'prod_gen'}, 'operatorInfo': {'name': 'Västtrafik', 'nameS': '279', 'nameN': '279', 'nameL': 'Västtrafik', 'id': '279'}, 'name': 'Länstrafik - Buss 74', 'internalName': 'Länstrafik - Buss 74', 'displayNumber': '74', 'num': '74', 'line': '74', 'lineId': '1279507400001', 'catOut': 'BLT', 'catIn': 'BLT', 'catCode': '7', 'cls': '128', 'catOutS': 'BLT', 'catOutL': 'Länstrafik - Buss', 'operatorCode': '279', 'operator': 'Västtrafik', 'admin': '279___', 'routeIdxFrom': 0, 'routeIdxTo': 6, 'matchId': '74;5074;76'}], 'Stops': {'Stop': [{'name': 'Partille centrum', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'routeIdx': 0, 'lon': 12.105252, 'lat': 57.738623, 'depPrognosisType': 'PROGNOSED', 'depTime': '17:42:00', 'depDate': '2025-01-28', 'depDir': 'Angered centrum (Göteborg kn)', 'minimumChangeDuration': 'PT3M'}, {'name': 'Artles torg (Partille kn)', 'id': 'A=1@O=Artles torg (Partille kn)@X=12093719@Y=57739971@U=1@L=740060017@', 'extId': '740060017', 'routeIdx': 1, 'lon': 12.093719, 'lat': 57.739971, 'depTime': '17:43:00', 'depDate': '2025-01-28', 'arrTime': '17:43:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, {'name': 'Jennyhill (Partille kn)', 'id': 'A=1@O=Jennyhill (Partille kn)@X=12085062@Y=57741301@U=1@L=740060018@', 'extId': '740060018', 'routeIdx': 2, 'lon': 12.085062, 'lat': 57.741301, 'depTime': '17:44:00', 'depDate': '2025-01-28', 'arrTime': '17:44:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT0S'}, {'name': 'Bergsjön Komettorget (Göteborg kn)', 'id': 'A=1@O=Bergsjön Komettorget (Göteborg kn)@X=12071398@Y=57751091@U=1@L=740025646@', 'extId': '740025646', 'routeIdx': 3, 'lon': 12.071398, 'lat': 57.751091, 'depTime': '17:51:00', 'depDate': '2025-01-28', 'arrTime': '17:51:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, {'name': 'Rymdtorget Buss (Göteborg kn)', 'id': 'A=1@O=Rymdtorget Buss (Göteborg kn)@X=12072783@Y=57756934@U=1@L=740059521@', 'extId': '740059521', 'routeIdx': 4, 'lon': 12.072783, 'lat': 57.756934, 'depTime': '17:55:00', 'depDate': '2025-01-28', 'arrTime': '17:55:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, {'name': 'Bergsjödalen (Göteborg kn)', ...
# No valid connection found in this route.
# Connection Data: {'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '17:51:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Angered Kyrka (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@', 'extId': '740015553', 'lon': 12.095975, 'lat': 57.788297, 'routeIdx': 22, 'prognosisType': 'PROGNOSED', 'time': '18:26:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'ServiceDays': [{'planningPeriodBegin': '2025-01-02', 'planningPeriodEnd': '2025-06-15', 'sDaysR': 'mån - fre', 'sDaysI': 'utom 18., 21. apr, 1., 29. maj, 6. jun', 'sDaysB': '0000027CF9F3E7CF9F3E7CF9F3C3CE9F3E7CE9E3E0'}], 'LegList': {'Leg': [{'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '17:51:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Göteborg Svingeln', 'type': 'ST', 'id': 'A=1@O=Göteborg Svingeln@X=11991080@Y=57713147@U=1@L=740015597@', 'extId': '740015597', 'lon': 11.99108, 'lat': 57.713147, 'routeIdx': 1, 'prognosisType': 'PROGNOSED', 'time': '17:59:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas', 'key': 'EG', 'type': 'A', 'routeIdxFrom': 0, 'routeIdxTo': 1, 'txtN': 'Lag 2015:953 tillämpas'}]}, 'JourneyDetailRef': {'ref': '1|101980|0|1|28012025'}, 'JourneyStatus': 'P', 'Product': [{'icon': {'res': 'prod_gen'}, 'operatorInfo': {'name': 'Västtrafik', 'nameS': '279', 'nameN': '279', 'nameL': 'Västtrafik', 'id': '279'}, 'name': 'Länstrafik - Buss X1', 'internalName': 'Länstrafik - Buss X1', 'displayNumber': 'X1', 'num': 'X1', 'line': 'X1', 'lineId': '1279521200001', 'catOut': 'BLT', 'catIn': 'BLT', 'catCode': '7', 'cls': '128', 'catOutS': 'BLT', 'catOutL': 'Länstrafik - Buss', 'operatorCode': '279', 'operator': 'Västtrafik', 'admin': '279___', 'routeIdxFrom': 0, 'routeIdxTo': 1, 'matchId': 'X1;5212;159'}], 'Stops': {'Stop': [{'name': 'Partille centrum', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'routeIdx': 0, 'lon': 12.105252, 'lat': 57.738623, 'depPrognosisType': 'PROGNOSED', 'depTime': '17:51:00', 'depDate': '2025-01-28', 'depDir': 'Hornkamsgatan (Göteborg kn)', 'minimumChangeDuration': 'PT3M'}, {'name': 'Göteborg Svingeln', 'id': 'A=1@O=Göteborg Svingeln@X=11991080@Y=57713147@U=1@L=740015597@', 'extId': '740015597', 'routeIdx': 1, 'lon': 11.99108, 'lat': 57.713147, 'arrTime': '17:59:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT5M'}]}, 'JourneyDetail': {'ref': '1|101980|0|1|28012025', 'dayOfOperation': '2025-01-28'}, 'id': '0', 'idx': 0, 'name': 'Länstrafik - Buss X1', 'number': 'X1', 'category': 'BLT', 'type': 'JNY', 'reachable': True, 'waitingState': 'UNDEF', 'direction': 'Hornkamsgatan (Göteborg kn)', 'directionFlag': '1', 'duration': 'PT8M', 'minimumChangeDuration': 'PT5M'}, {'Origin': {'name': 'Göteborg Svingeln', 'type': 'ST', 'id': 'A=1@O=Göteborg Svingeln@X=11991080@Y=57713147@U=1@L=740015597@', 'extId': '740015597', 'lon': 11.99108, 'lat': 57.713147, 'routeIdx': 16, 'prognosisType': 'PROGNOSED', 'time': '18:06:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'Destination': {'name': 'Angered Kyrka (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@', 'extId': '740015553', 'lon': 12.095975, 'lat': 57.788297, 'routeIdx': 22, 'prognosisType': 'PROGNOSED', 'time': '18:26:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas', 'key': 'EG', 'type': 'A', 'routeIdxFrom': 16, 'routeIdxTo': 22, 'txtN': ...
# No valid connection found in this route.
# Connection Data: {'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '18:02:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Angered Kyrka (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Angered Kyrka (Göteborg kn)@X=12095975@Y=57788297@U=1@L=740015553@', 'extId': '740015553', 'lon': 12.095975, 'lat': 57.788297, 'routeIdx': 21, 'prognosisType': 'PROGNOSED', 'time': '18:41:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'ServiceDays': [{'planningPeriodBegin': '2025-01-02', 'planningPeriodEnd': '2025-06-15', 'sDaysR': 'mån - fre', 'sDaysI': 'utom 18., 21. apr, 1., 29. maj, 6. jun', 'sDaysB': '0000027CF9F3E7CF9F3E7CF9F3C3CE9F3E7CE9E3E0'}], 'LegList': {'Leg': [{'Origin': {'name': 'Partille centrum', 'type': 'ST', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'lon': 12.105252, 'lat': 57.738623, 'routeIdx': 0, 'prognosisType': 'PROGNOSED', 'time': '18:02:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, 'Destination': {'name': 'Linnarhultsvägen (Göteborg kn)', 'type': 'ST', 'id': 'A=1@O=Linnarhultsvägen (Göteborg kn)@X=12064593@Y=57776611@U=1@L=740059414@', 'extId': '740059414', 'lon': 12.064593, 'lat': 57.776611, 'routeIdx': 6, 'prognosisType': 'PROGNOSED', 'time': '18:20:00', 'date': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, 'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas', 'key': 'EG', 'type': 'A', 'routeIdxFrom': 0, 'routeIdxTo': 6, 'txtN': 'Lag 2015:953 tillämpas'}]}, 'JourneyDetailRef': {'ref': '1|28001|3|1|28012025'}, 'JourneyStatus': 'P', 'Product': [{'icon': {'res': 'prod_gen'}, 'operatorInfo': {'name': 'Västtrafik', 'nameS': '279', 'nameN': '279', 'nameL': 'Västtrafik', 'id': '279'}, 'name': 'Länstrafik - Buss 74', 'internalName': 'Länstrafik - Buss 74', 'displayNumber': '74', 'num': '74', 'line': '74', 'lineId': '1279507400001', 'catOut': 'BLT', 'catIn': 'BLT', 'catCode': '7', 'cls': '128', 'catOutS': 'BLT', 'catOutL': 'Länstrafik - Buss', 'operatorCode': '279', 'operator': 'Västtrafik', 'admin': '279___', 'routeIdxFrom': 0, 'routeIdxTo': 6, 'matchId': '74;5074;78'}], 'Stops': {'Stop': [{'name': 'Partille centrum', 'id': 'A=1@O=Partille centrum@X=12105252@Y=57738623@U=1@L=740015667@', 'extId': '740015667', 'routeIdx': 0, 'lon': 12.105252, 'lat': 57.738623, 'depPrognosisType': 'PROGNOSED', 'depTime': '18:02:00', 'depDate': '2025-01-28', 'depDir': 'Angered centrum (Göteborg kn)', 'minimumChangeDuration': 'PT3M'}, {'name': 'Artles torg (Partille kn)', 'id': 'A=1@O=Artles torg (Partille kn)@X=12093719@Y=57739971@U=1@L=740060017@', 'extId': '740060017', 'routeIdx': 1, 'lon': 12.093719, 'lat': 57.739971, 'depTime': '18:03:00', 'depDate': '2025-01-28', 'arrTime': '18:03:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT5M'}, {'name': 'Jennyhill (Partille kn)', 'id': 'A=1@O=Jennyhill (Partille kn)@X=12085062@Y=57741301@U=1@L=740060018@', 'extId': '740060018', 'routeIdx': 2, 'lon': 12.085062, 'lat': 57.741301, 'depTime': '18:04:00', 'depDate': '2025-01-28', 'arrTime': '18:04:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT0S'}, {'name': 'Bergsjön Komettorget (Göteborg kn)', 'id': 'A=1@O=Bergsjön Komettorget (Göteborg kn)@X=12071398@Y=57751091@U=1@L=740025646@', 'extId': '740025646', 'routeIdx': 3, 'lon': 12.071398, 'lat': 57.751091, 'depTime': '18:11:00', 'depDate': '2025-01-28', 'arrTime': '18:11:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, {'name': 'Rymdtorget Buss (Göteborg kn)', 'id': 'A=1@O=Rymdtorget Buss (Göteborg kn)@X=12072783@Y=57756934@U=1@L=740059521@', 'extId': '740059521', 'routeIdx': 4, 'lon': 12.072783, 'lat': 57.756934, 'depTime': '18:15:00', 'depDate': '2025-01-28', 'arrTime': '18:15:00', 'arrDate': '2025-01-28', 'minimumChangeDuration': 'PT3M'}, {'name': 'Bergsjödalen (Göteborg kn)', ...
# No valid connection found in this route.
